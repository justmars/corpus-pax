# %%
from pathlib import Path

p = Path().home() / "code" / "corpus-entities" 
p.exists()
# Out:
# True

# %%
import seedir as sd
sd.seedir(p)
# Out:
# corpus-entities/
# ├─orgs/
# │ ├─efg-tax/
# │ │ ├─details.yaml
# │ │ └─avatar.jpeg
# │ ├─abcxyz-law/
# │ │ ├─details.yaml
# │ │ └─avatar.jpeg
# │ ├─legaltechph/
# │ │ ├─details.yaml
# │ │ └─avatar.jpeg
# │ └─apptitude/
# │   ├─details.yaml
# │   └─avatar.jpeg
# ├─README.md
# ├─.gitignore
# ├─members/
# │ ├─.DS_Store
# │ ├─0bot/
# │ │ ├─details.yaml
# │ │ └─avatar.jpeg
# │ ├─joy/
# │ │ ├─details.yaml
# │ │ └─avatar.jpeg
# │ ├─fernando/
# │ │ ├─details.yaml
# │ │ └─avatar.jpeg
# │ ├─mv/
# │ │ ├─details.yaml
# │ │ └─avatar.jpeg
# │ └─maria/
# │   ├─details.yaml
# │   └─avatar.jpeg
# └─.git/
#   ├─config
#   ├─objects/
#   │ ├─0d/
#   │ │ └─4f3908a997ca8befe831b8fda5c6414a204c25
#   │ ├─50/
#   │ │ └─f1d38792425bd574349124b63b486fb4e08151
#   │ ├─57/
#   │ │ └─8232c7f60aef58f3d39e8159c0f330312d5e7a
#   │ ├─9e/
#   │ │ └─2dd0209506dd4a01e5c72d85af747113ff06d7
#   │ ├─3c/
#   │ │ └─723fd37c79592bd01acd1fdd8b2949e6fdbdd7
#   │ ├─5f/
#   │ │ └─e7f6e6ebae59c0a5ed1cc3da9ef169f05b5b84
# ...
